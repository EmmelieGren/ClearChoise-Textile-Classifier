# %% [markdown]
# # Flower model
# ### Trained in Google Colab with 35 img.

# %%
from google.colab import files
import os

# %%
# %%bash
# git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# %%bash
# pip install -r yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# ...

# %%
os.mkdir('train')

# %%
os.chdir('/content/yolov5/data') #yaml
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2708c758-f107-4893-89c0-5ac05dc01bd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2708c758-f107-4893-89c0-5ac05dc01bd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ladda upp träningsbilderna .jpg och deras .txt annoteringsfiler till AIn
os.chdir('/content/train')
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4807905e-12e2-4ac3-a615-0f03f3d3f484" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4807905e-12e2-4ac3-a615-0f03f3d3f484">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Batch = 16
# ### Epochs = 100

# %%
# %%bash
# cd /content/yolov5
# python train.py --img 640 --batch 16 --epochs 100 --data data/my_YAML_file.yaml --weights yolov5s.pt
# Out:
# 2024-02-28 10:13:08.194576: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 10:13:08.194632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 10:13:08.196648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Testning

# %%
from PIL import Image
import torch
from IPython.display import display
from google.colab import files

# %%
# Load YOLOv5 model from local path
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/exp2/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-2-28 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
uploaded_test = files.upload()
# Out:
#      <input type="file" id="files-2d0077f3-6ee8-4f17-bf02-0c729d21c137" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d0077f3-6ee8-4f17-bf02-0c729d21c137">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# dags att ladda hem modellen
#files.download('/content/yolov5/runs/train/exp5/weights/best.pt')

# %%
image_path = next(iter(uploaded_test))
for image_name in uploaded_test.keys():
    input_image = Image.open(image_name)

    results = model(input_image)

    display(results.show())
